# %% [markdown]
# # Dataset & Model Exploration
# Explore the dataset and verify model loading before running the full benchmark.

# %%
import sys
sys.path.insert(0, '../src')

from benchmark.models import get_model, ALL_MODEL_IDS
print('Available models:', ALL_MODEL_IDS)

# %%
# Quick single-image embed test
from PIL import Image
import numpy as np

model = get_model('fashion-clip')
model.load()

img = Image.new('RGB', (224, 224), color=(128, 64, 200))
vec = model.embed(img)
print(f'Embedding shape: {vec.shape}, norm: {np.linalg.norm(vec):.4f}')
